# %% [markdown]
# ### fin_dashboard

# %% [markdown]
# # DASHBOARD: Monthly monitoring salary and expenditure
#
# Below outlines key expenditure items to track on a monthly basis. This provides information to understand our monthly performance of for savings and expenditure. It also enables any unexpected changes in salary to be identified.
#
# Key items include:
# - checking account balance monitoring - which captures savings
# - monthly credit card totals
# - key expenditure items such as: Amazon purhcases and groceries
# - monthly salary amounts

# %% [markdown]
# # How to use
# Updated csv files need to be saved into the random_data folder in our finances project.
#
# Then these updated files need to be loaded into `~/Jupyter/our_finances/random_data/random_dashboard/fin_data_cleaning.ipynb`
#
# Need to update:
# - **Each month**. Each month when new data comes in, update the pd.read_csv file.
# - **Beginning of new year.** For `credit_year_mean`: Need to add an extra color into `credit_year_mean['colors']` and add year into `credit_year_mean['period']`

# %%
# %run ~/Jupyter/our_finances/random_data/random_dashboard/fin_plot_functions_rand.ipynb

# %%
# %run ~/Jupyter/our_finances/random_data/random_dashboard/fin_data_cleaning_rand.ipynb

# %% [markdown]
# # The headlines indicators

# %%
credit_card_performance(credit_year_mean)
# Out:
# LOW CREDIT CARD: Below mean credit card total last month

# %% [markdown]
# # Savings: Checking account balance

# %%
# need to input year
monthly_savings_bar(2020)

# %% [markdown]
# # Monthly expenditure analysis

# %%
# Inputs into function can include: none, 2018, 2019, 2020
month_expense_line()

# %%
avg_yearly_credit_balance(credit_year_mean, 'Average Credit Balances by year incl last month')

# %% [markdown]
# # Salary comparison

# %%
month_salary()

# %% [markdown]
# # Annual spending across key categories

# %%
category_comparison(misc_categories, big_categories)

# %%
category_comparison(baby_categories, dining_entertainment)

# %%
category_comparison(auto_transport, savings_vanguard)
